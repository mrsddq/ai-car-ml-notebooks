# %% [markdown]
# # What we will learn?
# - Simple linear regression
# - Python packages
# - First regression model

# %% [markdown]
# # Python Packages
# - Numpy
# - Pandas
# - Scipy
# - Skilearn
# - Matplotlib
# - Statsmodel
# - Seaborn

# %% [markdown]
# # Linear Regression
#
# Linear regression helps us understand the relationship between the dependent variable and one or more independent variables by fitting a linear equation to the observed data.
# $$
# {Y_i} = \beta_0 + \beta_1{X_i}
# $$
#
# ${Y_i}$ = Dependent variable,
# ${\beta_0}$ = Constant/Intercept,
# ${\beta_1}$ = Slope/Coefficient,
# ${X_i}$ = Independent Variable.

# %%
#import all the important packages
#!pip install seaborn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %% [markdown]
# # Load the data

# %%
data=pd.read_csv('Data.csv')
data
# Out:
#      SAT Score   GPA
# 0          847  3.99
# 1          973  3.98
# 2         1440  1.95
# 3         1540  3.98
# 4          900  1.55
# ..         ...   ...
# 176        853  4.00
# 177        887  2.00
# 178       1373  3.99
# 179       1573  3.63
# 180        507  4.00
#
# [181 rows x 2 columns]

# %%
data.describe()
# Out:
#          SAT Score         GPA
# count   181.000000  181.000000
# mean   1000.000000    2.617901
# std     349.293573    1.559243
# min     400.000000    0.000000
# 25%     700.000000    1.390000
# 50%    1000.000000    3.370000
# 75%    1300.000000    3.970000
# max    1600.000000    4.000000

# %% [markdown]
# # First Regression

# %% [markdown]
# Define the dependent and independent variable

# %%
# y is the dependent variable
# x is the independent variable
y=data['GPA']
x1=data['SAT Score']

# %% [markdown]
# ## Explore the data

# %%
plt.scatter(x1,y)
plt.xlabel('SAT score', fontsize=15)
plt.ylabel('GPA', fontsize=15)
plt.show()

# %%
x = sm.add_constant(x1)
result = sm.OLS(y,x).fit() #OLS = Ordinary least square
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    GPA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.2914
# Date:                Mon, 15 Sep 2025   Prob (F-statistic):              0.590
# Time:                        12:31:11   Log-Likelihood:                -336.58
# No. Observations:                 181   AIC:                             677.2
# Df Residuals:                     179   BIC:                             683.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.7979      0.353      7.925      0.000       2.101       3.495
# SAT Score     -0.0002      0.000     -0.540      0.590      -0.001       0.000
# ==============================================================================
# Omnibus:                       54.950   Durbin-Watson:                   1.859
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.530
# Skew:                          -0.751   Prob(JB):                     2.86e-06
# Kurtosis:                       1.938   Cond. No.                     3.22e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.22e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
plt.scatter(x1,y)
yhat = -0.0002*x1+(2.7979)
fig = plt.plot(x1,yhat,lw=4, c='orange',label='regression line')
plt.xlabel('SAT', fontsize=15)
plt.ylabel('GPA', fontsize=15)
plt.show()

# %%
new_data = pd.DataFrame({'const':1,'SAT':[1700,1670]})
new_data = new_data[['const','SAT']]
new_data
# Out:
#    const   SAT
# 0      1  1700
# 1      1  1670

# %%
new_data.rename(index={0:'Bob',1:'Alice'})
# Out:
#        const   SAT
# Bob        1  1700
# Alice      1  1670

# %%
predictions = result.predict(new_data)
predictions
# Out:
# 0    2.491923
# 1    2.497322
# dtype: float64
